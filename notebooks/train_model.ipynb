# %%
import sys
import os
# Add project root to sys.path (one directory up from the notebook)
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
sys.path.insert(0, project_root)

from src.data_loader import ShanghaiTechDataset
from src.finetune_metrics import train_model
from torchvision import transforms

# %%
transform = transforms.Compose([
    transforms.Resize((256, 256)),
    transforms.ToTensor()
])

# %%
train_dataset = ShanghaiTechDataset("../data/ShanghaiTech", part="part_A", split="train_data", transform=transform)
val_dataset = ShanghaiTechDataset("../data/ShanghaiTech", part="part_A", split="test_data", transform=transform)

# %%
train_model(train_dataset, val_dataset, epochs=15)
# Out:
# Using Apple Metal Performance Shaders (MPS)
# Epoch 1/15 - Train MAE: 537.30 - Val MAE: 422.58
# Epoch 2/15 - Train MAE: 526.14 - Val MAE: 412.04
# Epoch 3/15 - Train MAE: 509.30 - Val MAE: 367.43
# Epoch 4/15 - Train MAE: 485.28 - Val MAE: 385.14
# Epoch 5/15 - Train MAE: 448.43 - Val MAE: 335.31
# Epoch 6/15 - Train MAE: 410.84 - Val MAE: 309.05
# Epoch 7/15 - Train MAE: 365.05 - Val MAE: 280.20
# Epoch 8/15 - Train MAE: 323.39 - Val MAE: 213.95
# Epoch 9/15 - Train MAE: 275.66 - Val MAE: 230.76
# Epoch 10/15 - Train MAE: 237.12 - Val MAE: 235.79
# Epoch 11/15 - Train MAE: 217.77 - Val MAE: 193.00
# Epoch 12/15 - Train MAE: 181.46 - Val MAE: 196.10
# Epoch 13/15 - Train MAE: 158.14 - Val MAE: 166.36
# Epoch 14/15 - Train MAE: 161.44 - Val MAE: 169.20
# Epoch 15/15 - Train MAE: 124.33 - Val MAE: 136.58
# Saving model to outputs/metrics_plot.png
# Saving model to saved/resnet50_finetuned.pth
