# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd '/content/drive/MyDrive/CV-crowd-flow-estimation-/notebooks'
# Out:
# /content/drive/MyDrive/CV-crowd-flow-estimation-/notebooks

# %%
# !pwd
# Out:
# /content/drive/MyDrive/CV-crowd-flow-estimation-/notebooks

# %%
import sys
import os
# Add project root to sys.path (one directory up from the notebook)
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
sys.path.insert(0, project_root)

from src.data_loader import ShanghaiTechDataModule
from src.finetune_metrics import train_model
from torchvision import transforms

# %%
transform = transforms.Compose([
    transforms.Resize((256, 256)),
    transforms.ToTensor()
])

# %% [markdown]
# # Part A

# %%
data_module_A = ShanghaiTechDataModule("../data/ShanghaiTech", "part_A", validation_split=0.1)

# %%
# Part A: train all three backbones on the Part A dataset
train_model(data_module_A, model_name="resnet50", epochs=25, save_path="../models/part_A_resnet50_model.pth")
# Out:
# Using CUDA: Tesla T4
# [resnet50] Epoch 1/25  Train MAE: 535.065  Val MAE: 508.966
# [resnet50] Epoch 2/25  Train MAE: 508.152  Val MAE: 446.244
# [resnet50] Epoch 3/25  Train MAE: 458.225  Val MAE: 348.599
# [resnet50] Epoch 4/25  Train MAE: 387.736  Val MAE: 320.507
# [resnet50] Epoch 5/25  Train MAE: 319.203  Val MAE: 255.923
# [resnet50] Epoch 6/25  Train MAE: 260.700  Val MAE: 207.826
# [resnet50] Epoch 7/25  Train MAE: 221.951  Val MAE: 350.997
# [resnet50] Epoch 8/25  Train MAE: 217.995  Val MAE: 380.588
# [resnet50] Epoch 9/25  Train MAE: 191.200  Val MAE: 225.709
# [resnet50] Epoch 10/25  Train MAE: 172.879  Val MAE: 223.904
# [resnet50] Epoch 11/25  Train MAE: 175.139  Val MAE: 211.163
# [resnet50] Epoch 12/25  Train MAE: 162.106  Val MAE: 140.422
# [resnet50] Epoch 13/25  Train MAE: 140.206  Val MAE: 223.199
# [resnet50] Epoch 14/25  Train MAE: 153.396  Val MAE: 164.920
# [resnet50] Epoch 15/25  Train MAE: 169.329  Val MAE: 254.837
# ...

# %%
train_model(data_module_A, model_name="vgg19_bn", epochs=25, save_path="../models/part_A_vgg19_bn_model.pth")
# Out:
# Using CUDA: Tesla T4
# [vgg19_bn] Epoch 1/25  Train MAE: 495.347  Val MAE: 393.490
# [vgg19_bn] Epoch 2/25  Train MAE: 331.011  Val MAE: 254.952
# [vgg19_bn] Epoch 3/25  Train MAE: 213.669  Val MAE: 317.221
# [vgg19_bn] Epoch 4/25  Train MAE: 179.530  Val MAE: 258.954
# [vgg19_bn] Epoch 5/25  Train MAE: 211.746  Val MAE: 269.760
# [vgg19_bn] Epoch 6/25  Train MAE: 184.461  Val MAE: 232.319
# [vgg19_bn] Epoch 7/25  Train MAE: 179.186  Val MAE: 176.065
# [vgg19_bn] Epoch 8/25  Train MAE: 162.520  Val MAE: 187.826
# [vgg19_bn] Epoch 9/25  Train MAE: 142.720  Val MAE: 203.720
# [vgg19_bn] Epoch 10/25  Train MAE: 132.805  Val MAE: 252.612
# [vgg19_bn] Epoch 11/25  Train MAE: 123.542  Val MAE: 177.361
# [vgg19_bn] Epoch 12/25  Train MAE: 121.119  Val MAE: 178.201
# [vgg19_bn] Epoch 13/25  Train MAE: 91.689  Val MAE: 186.280
# [vgg19_bn] Epoch 14/25  Train MAE: 102.561  Val MAE: 179.131
# [vgg19_bn] Epoch 15/25  Train MAE: 107.103  Val MAE: 216.503
# ...

# %% [markdown]
# # Part B

# %%
data_module_B = ShanghaiTechDataModule("../data/ShanghaiTech", "part_B", validation_split=0.1)

# %%
# Part B: train all three backbones on the Part B dataset
train_model(data_module_B, model_name="resnet50", epochs=25, save_path="../models/part_B_resnet50_model.pth")
# Out:
# Using CUDA: Tesla T4
# [resnet50] Epoch 1/25  Train MAE: 110.235  Val MAE: 102.421
# [resnet50] Epoch 2/25  Train MAE: 72.118  Val MAE: 39.247
# [resnet50] Epoch 3/25  Train MAE: 40.583  Val MAE: 46.207
# [resnet50] Epoch 4/25  Train MAE: 31.570  Val MAE: 32.013
# [resnet50] Epoch 5/25  Train MAE: 33.915  Val MAE: 30.785
# [resnet50] Epoch 6/25  Train MAE: 30.442  Val MAE: 26.717
# [resnet50] Epoch 7/25  Train MAE: 31.034  Val MAE: 25.343
# [resnet50] Epoch 8/25  Train MAE: 29.847  Val MAE: 24.851
# [resnet50] Epoch 9/25  Train MAE: 27.301  Val MAE: 21.174
# [resnet50] Epoch 10/25  Train MAE: 28.033  Val MAE: 29.707
# [resnet50] Epoch 11/25  Train MAE: 24.636  Val MAE: 31.759
# [resnet50] Epoch 12/25  Train MAE: 19.795  Val MAE: 28.544
# [resnet50] Epoch 13/25  Train MAE: 21.434  Val MAE: 26.794
# [resnet50] Epoch 14/25  Train MAE: 27.537  Val MAE: 33.499
# [resnet50] Epoch 15/25  Train MAE: 19.322  Val MAE: 25.282
# [resnet50] Epoch 16/25  Train MAE: 16.487  Val MAE: 31.294
# ...

# %%
train_model(data_module_B, model_name="vgg19_bn", epochs=25, save_path="../models/part_B_vgg19_bn_model.pth")
# Out:
# Using CUDA: Tesla T4
# [vgg19_bn] Epoch 1/25  Train MAE: 66.399  Val MAE: 123.106
# [vgg19_bn] Epoch 2/25  Train MAE: 36.667  Val MAE: 37.050
# [vgg19_bn] Epoch 3/25  Train MAE: 31.687  Val MAE: 21.404
# [vgg19_bn] Epoch 4/25  Train MAE: 27.456  Val MAE: 24.532
# [vgg19_bn] Epoch 5/25  Train MAE: 26.082  Val MAE: 56.410
# [vgg19_bn] Epoch 6/25  Train MAE: 26.530  Val MAE: 49.281
# [vgg19_bn] Epoch 7/25  Train MAE: 24.304  Val MAE: 45.227
# [vgg19_bn] Epoch 8/25  Train MAE: 20.358  Val MAE: 27.086
# [vgg19_bn] Epoch 9/25  Train MAE: 16.922  Val MAE: 23.670
# [vgg19_bn] Epoch 10/25  Train MAE: 17.950  Val MAE: 22.616
# [vgg19_bn] Epoch 11/25  Train MAE: 16.919  Val MAE: 40.336
# [vgg19_bn] Epoch 12/25  Train MAE: 22.825  Val MAE: 25.611
# [vgg19_bn] Epoch 13/25  Train MAE: 16.382  Val MAE: 22.899
# [vgg19_bn] Epoch 14/25  Train MAE: 17.926  Val MAE: 33.712
# [vgg19_bn] Epoch 15/25  Train MAE: 16.651  Val MAE: 31.239
# [vgg19_bn] Epoch 16/25  Train MAE: 18.268  Val MAE: 32.569
# ...
