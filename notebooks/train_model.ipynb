# %%
import sys
import os
# Add project root to sys.path (one directory up from the notebook)
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
sys.path.insert(0, project_root)

from src.data_loader import ShanghaiTechDataModule
from src.finetune_metrics import train_model
from torchvision import transforms

# %%
transform = transforms.Compose([
    transforms.Resize((256, 256)),
    transforms.ToTensor()
])

# %% [markdown]
# # Part A

# %%
data_module = ShanghaiTechDataModule("../data/ShanghaiTech", "part_A", validation_split=0.1)

# %%
train_model(data_module, epochs=15, save_path="../models/part_A_model.pth")
# Out:
# Using Apple Metal Performance Shaders (MPS)
# /opt/homebrew/Caskroom/miniconda/base/lib/python3.12/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /opt/homebrew/Caskroom/miniconda/base/lib/python3.12/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# /opt/homebrew/Caskroom/miniconda/base/lib/python3.12/site-packages/torch/utils/data/dataloader.py:683: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# ...

# %% [markdown]
# # Part B

# %%
data_module = ShanghaiTechDataModule("../data/ShanghaiTech", "part_B", validation_split=0.1)

# %%
train_model(data_module, epochs=15, save_path="../models/part_B_model.pth")
# Out:
# Using Apple Metal Performance Shaders (MPS)
# Epoch 1/15 - Train MAE: 108.17 - Val MAE: 89.45
# Epoch 2/15 - Train MAE: 67.18 - Val MAE: 51.76
# Epoch 3/15 - Train MAE: 37.78 - Val MAE: 50.62
# Epoch 4/15 - Train MAE: 32.29 - Val MAE: 40.01
# Epoch 5/15 - Train MAE: 37.75 - Val MAE: 30.73
# Epoch 6/15 - Train MAE: 27.93 - Val MAE: 26.83
# Epoch 7/15 - Train MAE: 27.51 - Val MAE: 26.05
# Epoch 8/15 - Train MAE: 27.33 - Val MAE: 29.40
# Epoch 9/15 - Train MAE: 23.47 - Val MAE: 25.13
# Epoch 10/15 - Train MAE: 28.21 - Val MAE: 27.47
# Epoch 11/15 - Train MAE: 25.90 - Val MAE: 30.32
# Epoch 12/15 - Train MAE: 27.66 - Val MAE: 20.45
# Epoch 13/15 - Train MAE: 25.73 - Val MAE: 30.91
# Epoch 14/15 - Train MAE: 23.33 - Val MAE: 32.50
# Epoch 15/15 - Train MAE: 21.06 - Val MAE: 29.31
# Saving model to outputs/metrics_plot.png
# Saving model to ../models/part_B_model.pth
