# %%
import sys
import os
# Add project root to sys.path (one directory up from the notebook)
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
sys.path.insert(0, project_root)

from src.data_loader import ShanghaiTechDataModule
from src.finetune_metrics import train_model
from torchvision import transforms

# %%
transform = transforms.Compose([
    transforms.Resize((256, 256)),
    transforms.ToTensor()
])

# %% [markdown]
# # Part A

# %%
data_module_A = ShanghaiTechDataModule("../data/ShanghaiTech", "part_A", validation_split=0.1)

# %%
# Part A: train all three backbones on the Part A dataset
train_model(data_module_A, model_name="resnet50", epochs=15, save_path="../models/part_A_resnet50_model.pth")
train_model(data_module_A, model_name="vgg19_bn", epochs=15, save_path="../models/part_A_vgg19_bn_model.pth")
# Out:
# Using CPU
# C:\Users\hp\AppData\Roaming\Python\Python311\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\Users\hp\AppData\Roaming\Python\Python311\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 2
#       1 # Part A: train all three backbones on the Part A dataset
# ----> 2 train_model(data_module_A, model_name="resnet50", epochs=15, save_path="../models/part_A_resnet50_model.pth")
#       3 train_model(data_module_A, model_name="vgg19_bn", epochs=15, save_path="../models/part_A_vgg19_bn_model.pth")
#
# File c:\Users\hp\Desktop\Master - AI\Semestre II\Computer Vision\CV-crowd-flow-estimation-\src\finetune_metrics.py:60, in train_model(data_module, model_name, epochs, lr, batch_size, save_path)
#      57     print("Using CPU")
#      59 # get backbone + identify head parameters for optimizer
# ---> 60 model, head = get_backbone(model_name, pretrained=True, freeze_backbone=True)
#      61 model = model.to(device)
#      63 # only train head parameters
#
# File c:\Users\hp\Desktop\Master - AI\Semestre II\Computer Vision\CV-crowd-flow-estimation-\src\finetune_metrics.py:35, in get_backbone(model_name, pretrained, freeze_backbone)
#      31     raise ValueError(f"Unknown model_name {model_name}")
#      33 if freeze_backbone:
#      34     # freeze all parameters in the backbone
# ---> 35     for p in backbone_params.parameters():
#      36         p.requires_grad = False
#      38 return model, head_params
#
# AttributeError: 'tuple' object has no attribute 'parameters'

# %% [markdown]
# # Part B

# %%
data_module_B = ShanghaiTechDataModule("../data/ShanghaiTech", "part_B", validation_split=0.1)

# %%
# Part B: train all three backbones on the Part B dataset
train_model(data_module_B, model_name="resnet50", epochs=15, save_path="../models/part_B_resnet50_model.pth")
train_model(data_module_B, model_name="vgg19_bn", epochs=15, save_path="../models/part_B_vgg19_bn_model.pth")
# Out:
# Using Apple Metal Performance Shaders (MPS)
# Epoch 1/2 - Train MAE: 110.85 - Val MAE: 78.64
# Epoch 2/2 - Train MAE: 73.68 - Val MAE: 45.03
# Results already exists at outputs/metrics_plot.png, overwriting.
# Model already exists at ../models/part_B_model.pth, overwriting.
